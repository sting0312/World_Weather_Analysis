# %%
# Dependencies 
import pandas as pd 
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 780

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        
        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | kiunga
# Processing Record 9 of Set 1 | san luis obispo
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | itoman
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | kamenskoye
# City not found. Skipping
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 18 of Set 1 | cukai
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | bida
# Processing Record 22 of Set 1 | aykhal
# Processing Record 23 of Set 1 | georgiyevskoye
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | geraldton
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | broome
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | taltal
# Processing Record 34 of Set 1 | pitimbu
# Processing Record 35 of Set 1 | gao
# Processing Record 36 of Set 1 | mehamn
# Processing Record 37 of Set 1 | diphu
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | yanliang
# Processing Record 40 of Set 1 | manjacaze
# Processing Record 41 of Set 1 | laramie
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | chulym
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | pekan
# Processing Record 46 of Set 1 | lakes entrance
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | turbat
# Processing Record 50 of Set 1 | vao
# Processing Record 1 of Set 2 | ketchikan
# Processing Record 2 of Set 2 | tkvarcheli
# City not found. Skipping
# Processing Record 3 of Set 2 | flinders
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 5 of Set 2 | hare bay
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | comodoro rivadavia
# Processing Record 9 of Set 2 | opunake
# Processing Record 10 of Set 2 | naze
# Processing Record 11 of Set 2 | ilulissat
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | miandrivazo
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | kayes
# Processing Record 16 of Set 2 | socorro
# Processing Record 17 of Set 2 | stepnoye
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | san andres
# Processing Record 23 of Set 2 | levokumskoye
# Processing Record 24 of Set 2 | shalya
# Processing Record 25 of Set 2 | pokhara
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | batticaloa
# Processing Record 29 of Set 2 | okhotsk
# Processing Record 30 of Set 2 | union
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | ishigaki
# Processing Record 33 of Set 2 | ancud
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 35 of Set 2 | bireun
# Processing Record 36 of Set 2 | jiazi
# Processing Record 37 of Set 2 | ercis
# Processing Record 38 of Set 2 | tilichiki
# Processing Record 39 of Set 2 | hay river
# Processing Record 40 of Set 2 | skibbereen
# Processing Record 41 of Set 2 | waddan
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | barra do corda
# Processing Record 44 of Set 2 | malavalli
# Processing Record 45 of Set 2 | tomatlan
# Processing Record 46 of Set 2 | karratha
# Processing Record 47 of Set 2 | anuchino
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | coquimbo
# Processing Record 50 of Set 2 | talnakh
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | pacifica
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | niono
# Processing Record 5 of Set 3 | rio verde de mato grosso
# Processing Record 6 of Set 3 | dunmore town
# Processing Record 7 of Set 3 | sfantu gheorghe
# Processing Record 8 of Set 3 | kampot
# Processing Record 9 of Set 3 | ljungby
# Processing Record 10 of Set 3 | terekli-mekteb
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | lolua
# City not found. Skipping
# Processing Record 13 of Set 3 | cockburn town
# Processing Record 14 of Set 3 | champerico
# Processing Record 15 of Set 3 | chingirlau
# Processing Record 16 of Set 3 | sentyabrskiy
# City not found. Skipping
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | atasu
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | sao paulo de olivenca
# Processing Record 21 of Set 3 | fort nelson
# Processing Record 22 of Set 3 | riyadh
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | gravdal
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | gamboula
# Processing Record 27 of Set 3 | contamana
# Processing Record 28 of Set 3 | bluff
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | andenes
# Processing Record 31 of Set 3 | aklavik
# Processing Record 32 of Set 3 | tarakan
# Processing Record 33 of Set 3 | darhan
# Processing Record 34 of Set 3 | mabua
# Processing Record 35 of Set 3 | mayumba
# Processing Record 36 of Set 3 | orlik
# Processing Record 37 of Set 3 | penzance
# Processing Record 38 of Set 3 | springfield
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping
# Processing Record 40 of Set 3 | new gloucester
# Processing Record 41 of Set 3 | isangel
# Processing Record 42 of Set 3 | fort-shevchenko
# Processing Record 43 of Set 3 | chagda
# City not found. Skipping
# Processing Record 44 of Set 3 | atuona
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | dicabisagan
# Processing Record 47 of Set 3 | cayenne
# Processing Record 48 of Set 3 | kapaa
# Processing Record 49 of Set 3 | baherden
# Processing Record 50 of Set 3 | ferme-neuve
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | palabuhanratu
# City not found. Skipping
# Processing Record 4 of Set 4 | uramita
# Processing Record 5 of Set 4 | nishihara
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | hvolsvollur
# Processing Record 9 of Set 4 | santa isabel do rio negro
# Processing Record 10 of Set 4 | krems
# Processing Record 11 of Set 4 | shelburne
# Processing Record 12 of Set 4 | taburbah
# City not found. Skipping
# Processing Record 13 of Set 4 | omboue
# Processing Record 14 of Set 4 | cervo
# Processing Record 15 of Set 4 | murud
# Processing Record 16 of Set 4 | pisco
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | beloha
# Processing Record 19 of Set 4 | concepcion
# Processing Record 20 of Set 4 | meulaboh
# Processing Record 21 of Set 4 | rumphi
# Processing Record 22 of Set 4 | frolovo
# Processing Record 23 of Set 4 | jinka
# Processing Record 24 of Set 4 | paamiut
# Processing Record 25 of Set 4 | tevriz
# Processing Record 26 of Set 4 | morondava
# Processing Record 27 of Set 4 | do gonbadan
# Processing Record 28 of Set 4 | santa rosa
# Processing Record 29 of Set 4 | naldurg
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping
# Processing Record 31 of Set 4 | touros
# Processing Record 32 of Set 4 | codrington
# Processing Record 33 of Set 4 | segou
# Processing Record 34 of Set 4 | chapais
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | college
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | chicama
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping
# Processing Record 40 of Set 4 | baraki barak
# Processing Record 41 of Set 4 | la ronge
# Processing Record 42 of Set 4 | wulanhaote
# City not found. Skipping
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | falealupo
# City not found. Skipping
# Processing Record 45 of Set 4 | russell
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | palatka
# Processing Record 48 of Set 4 | nadym
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | oga
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping
# Processing Record 2 of Set 5 | caravelas
# Processing Record 3 of Set 5 | albox
# Processing Record 4 of Set 5 | bloomingdale
# Processing Record 5 of Set 5 | royan
# Processing Record 6 of Set 5 | chokurdakh
# Processing Record 7 of Set 5 | yarada
# Processing Record 8 of Set 5 | attawapiskat
# City not found. Skipping
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | sala consilina
# Processing Record 11 of Set 5 | kambove
# Processing Record 12 of Set 5 | kenai
# Processing Record 13 of Set 5 | wexford
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | tsihombe
# City not found. Skipping
# Processing Record 16 of Set 5 | nizhniy odes
# Processing Record 17 of Set 5 | lashio
# Processing Record 18 of Set 5 | cuenca
# Processing Record 19 of Set 5 | dobele
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | ucluelet
# Processing Record 22 of Set 5 | juifang
# City not found. Skipping
# Processing Record 23 of Set 5 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 24 of Set 5 | havre-saint-pierre
# Processing Record 25 of Set 5 | ambilobe
# Processing Record 26 of Set 5 | haibowan
# City not found. Skipping
# Processing Record 27 of Set 5 | juneau
# Processing Record 28 of Set 5 | umzimvubu
# City not found. Skipping
# Processing Record 29 of Set 5 | port lincoln
# Processing Record 30 of Set 5 | yershov
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | puerto narino
# Processing Record 33 of Set 5 | cap malheureux
# Processing Record 34 of Set 5 | tikhvin
# Processing Record 35 of Set 5 | jiuquan
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | kargil
# Processing Record 38 of Set 5 | novomikhaylovskiy
# Processing Record 39 of Set 5 | kaspiyskiy
# Processing Record 40 of Set 5 | redlands
# Processing Record 41 of Set 5 | stornoway
# Processing Record 42 of Set 5 | dunda
# Processing Record 43 of Set 5 | batagay-alyta
# Processing Record 44 of Set 5 | oussouye
# Processing Record 45 of Set 5 | camacha
# Processing Record 46 of Set 5 | jiamusi
# Processing Record 47 of Set 5 | padang
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | mentok
# City not found. Skipping
# Processing Record 50 of Set 5 | port keats
# Processing Record 1 of Set 6 | inirida
# Processing Record 2 of Set 6 | ratnagiri
# Processing Record 3 of Set 6 | port-de-paix
# City not found. Skipping
# Processing Record 4 of Set 6 | richards bay
# Processing Record 5 of Set 6 | acapulco
# Processing Record 6 of Set 6 | boueni
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | deming
# Processing Record 9 of Set 6 | san juan de los lagos
# Processing Record 10 of Set 6 | teguise
# Processing Record 11 of Set 6 | bani walid
# Processing Record 12 of Set 6 | sao filipe
# Processing Record 13 of Set 6 | deloraine
# Processing Record 14 of Set 6 | arrifes
# Processing Record 15 of Set 6 | jamame
# Processing Record 16 of Set 6 | shahreza
# Processing Record 17 of Set 6 | malakal
# Processing Record 18 of Set 6 | coihaique
# Processing Record 19 of Set 6 | phimai
# Processing Record 20 of Set 6 | mastic beach
# Processing Record 21 of Set 6 | saint-pierre
# Processing Record 22 of Set 6 | coahuayana
# Processing Record 23 of Set 6 | calbuco
# Processing Record 24 of Set 6 | kaitangata
# Processing Record 25 of Set 6 | tornio
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping
# Processing Record 27 of Set 6 | mira
# Processing Record 28 of Set 6 | sivas
# Processing Record 29 of Set 6 | akdepe
# Processing Record 30 of Set 6 | ponta do sol
# Processing Record 31 of Set 6 | goldap
# Processing Record 32 of Set 6 | siderno
# Processing Record 33 of Set 6 | chara
# Processing Record 34 of Set 6 | singaraja
# Processing Record 35 of Set 6 | aksu
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | nikolskoye
# Processing Record 38 of Set 6 | severo-yeniseyskiy
# Processing Record 39 of Set 6 | sitka
# Processing Record 40 of Set 6 | haicheng
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | esperance
# Processing Record 43 of Set 6 | jasdan
# Processing Record 44 of Set 6 | peniche
# Processing Record 45 of Set 6 | bahia honda
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | burica
# City not found. Skipping
# Processing Record 49 of Set 6 | victoria
# Processing Record 50 of Set 6 | marawi
# Processing Record 1 of Set 7 | faya
# Processing Record 2 of Set 7 | vanavara
# Processing Record 3 of Set 7 | dimataling
# Processing Record 4 of Set 7 | bilibino
# Processing Record 5 of Set 7 | namatanai
# Processing Record 6 of Set 7 | karambakkudi
# Processing Record 7 of Set 7 | miram shah
# Processing Record 8 of Set 7 | moyale
# Processing Record 9 of Set 7 | bengkulu
# Processing Record 10 of Set 7 | ola
# Processing Record 11 of Set 7 | barhi
# Processing Record 12 of Set 7 | bonthe
# Processing Record 13 of Set 7 | ewo
# Processing Record 14 of Set 7 | rosarito
# Processing Record 15 of Set 7 | bargal
# City not found. Skipping
# Processing Record 16 of Set 7 | carutapera
# Processing Record 17 of Set 7 | thompson
# Processing Record 18 of Set 7 | umm lajj
# Processing Record 19 of Set 7 | sinjar
# Processing Record 20 of Set 7 | nyurba
# Processing Record 21 of Set 7 | ndele
# Processing Record 22 of Set 7 | souillac
# Processing Record 23 of Set 7 | teahupoo
# Processing Record 24 of Set 7 | arraial do cabo
# Processing Record 25 of Set 7 | ahipara
# Processing Record 26 of Set 7 | krasnoarmeysk
# Processing Record 27 of Set 7 | bajil
# Processing Record 28 of Set 7 | douentza
# Processing Record 29 of Set 7 | tawau
# Processing Record 30 of Set 7 | honningsvag
# Processing Record 31 of Set 7 | korla
# Processing Record 32 of Set 7 | nemuro
# Processing Record 33 of Set 7 | onda
# Processing Record 34 of Set 7 | olafsvik
# Processing Record 35 of Set 7 | raudeberg
# Processing Record 36 of Set 7 | jahrom
# City not found. Skipping
# Processing Record 37 of Set 7 | omsukchan
# Processing Record 38 of Set 7 | luderitz
# Processing Record 39 of Set 7 | portland
# Processing Record 40 of Set 7 | port blair
# Processing Record 41 of Set 7 | eganville
# Processing Record 42 of Set 7 | husavik
# Processing Record 43 of Set 7 | imbituba
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | cabra
# Processing Record 46 of Set 7 | fortuna
# Processing Record 47 of Set 7 | pacific grove
# Processing Record 48 of Set 7 | jawhar
# Processing Record 49 of Set 7 | qandala
# Processing Record 50 of Set 7 | bubaque
# Processing Record 1 of Set 8 | leningradskiy
# Processing Record 2 of Set 8 | mantua
# Processing Record 3 of Set 8 | murgab
# Processing Record 4 of Set 8 | vallenar
# Processing Record 5 of Set 8 | tianpeng
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | iqaluit
# Processing Record 8 of Set 8 | achutupo
# Processing Record 9 of Set 8 | borogontsy
# Processing Record 10 of Set 8 | rio grande
# Processing Record 11 of Set 8 | nogent-le-rotrou
# Processing Record 12 of Set 8 | belaya gora
# Processing Record 13 of Set 8 | mercedes
# Processing Record 14 of Set 8 | tecolutla
# Processing Record 15 of Set 8 | laukaa
# Processing Record 16 of Set 8 | coruripe
# Processing Record 17 of Set 8 | podlesnoye
# Processing Record 18 of Set 8 | alekseyevka
# Processing Record 19 of Set 8 | otjiwarongo
# Processing Record 20 of Set 8 | kinablangan
# Processing Record 21 of Set 8 | northam
# Processing Record 22 of Set 8 | port elizabeth
# Processing Record 23 of Set 8 | girona
# Processing Record 24 of Set 8 | balkhash
# Processing Record 25 of Set 8 | klaksvik
# Processing Record 26 of Set 8 | ambon
# Processing Record 27 of Set 8 | viedma
# Processing Record 28 of Set 8 | preobrazheniye
# Processing Record 29 of Set 8 | jiddah
# City not found. Skipping
# Processing Record 30 of Set 8 | troitsko-pechorsk
# Processing Record 31 of Set 8 | presidencia roque saenz pena
# Processing Record 32 of Set 8 | san pedro
# Processing Record 33 of Set 8 | broken hill
# Processing Record 34 of Set 8 | lehututu
# Processing Record 35 of Set 8 | pietarsaari
# Processing Record 36 of Set 8 | solovetskiy
# City not found. Skipping
# Processing Record 37 of Set 8 | guerrero negro
# Processing Record 38 of Set 8 | mount vernon
# Processing Record 39 of Set 8 | itaituba
# Processing Record 40 of Set 8 | aswan
# Processing Record 41 of Set 8 | luwuk
# Processing Record 42 of Set 8 | santa maria
# Processing Record 43 of Set 8 | kieta
# Processing Record 44 of Set 8 | cherskiy
# Processing Record 45 of Set 8 | moussoro
# Processing Record 46 of Set 8 | grand gaube
# Processing Record 47 of Set 8 | sechura
# Processing Record 48 of Set 8 | novo aripuana
# Processing Record 49 of Set 8 | ilhabela
# Processing Record 50 of Set 8 | cravo norte
# Processing Record 1 of Set 9 | tres arroyos
# Processing Record 2 of Set 9 | tucuma
# Processing Record 3 of Set 9 | temaraia
# City not found. Skipping
# Processing Record 4 of Set 9 | jomalig
# City not found. Skipping
# Processing Record 5 of Set 9 | hecun
# Processing Record 6 of Set 9 | hengshui
# Processing Record 7 of Set 9 | lincoln
# Processing Record 8 of Set 9 | avera
# Processing Record 9 of Set 9 | dali
# Processing Record 10 of Set 9 | alofi
# Processing Record 11 of Set 9 | buta
# Processing Record 12 of Set 9 | malwan
# City not found. Skipping
# Processing Record 13 of Set 9 | baoro
# Processing Record 14 of Set 9 | mangan
# Processing Record 15 of Set 9 | bethel
# Processing Record 16 of Set 9 | tourlaville
# Processing Record 17 of Set 9 | tumannyy
# City not found. Skipping
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | todos santos
# Processing Record 20 of Set 9 | longlac
# City not found. Skipping
# Processing Record 21 of Set 9 | ekhabi
# Processing Record 22 of Set 9 | port macquarie
# Processing Record 23 of Set 9 | silleda
# Processing Record 24 of Set 9 | riohacha
# Processing Record 25 of Set 9 | verkhnyaya inta
# Processing Record 26 of Set 9 | chumikan
# Processing Record 27 of Set 9 | vicuna
# Processing Record 28 of Set 9 | bagontapay
# Processing Record 29 of Set 9 | te anau
# Processing Record 30 of Set 9 | kushikino
# Processing Record 31 of Set 9 | ksenyevka
# City not found. Skipping
# Processing Record 32 of Set 9 | hovd
# Processing Record 33 of Set 9 | alotau
# City not found. Skipping
# Processing Record 34 of Set 9 | urucui
# Processing Record 35 of Set 9 | west wendover
# Processing Record 36 of Set 9 | talas
# Processing Record 37 of Set 9 | sinnamary
# Processing Record 38 of Set 9 | asuncion
# Processing Record 39 of Set 9 | tautira
# Processing Record 40 of Set 9 | manicore
# Processing Record 41 of Set 9 | antofagasta
# Processing Record 42 of Set 9 | north bend
# Processing Record 43 of Set 9 | jati
# Processing Record 44 of Set 9 | bandarbeyla
# Processing Record 45 of Set 9 | berekum
# Processing Record 46 of Set 9 | pemangkat
# Processing Record 47 of Set 9 | strezhevoy
# Processing Record 48 of Set 9 | roma
# Processing Record 49 of Set 9 | tambura
# Processing Record 50 of Set 9 | biak
# Processing Record 1 of Set 10 | nabire
# Processing Record 2 of Set 10 | groa
# Processing Record 3 of Set 10 | gizo
# Processing Record 4 of Set 10 | tiarei
# Processing Record 5 of Set 10 | sorland
# Processing Record 6 of Set 10 | kollumerland
# City not found. Skipping
# Processing Record 7 of Set 10 | bennettsville
# Processing Record 8 of Set 10 | clyde river
# Processing Record 9 of Set 10 | tiksi
# Processing Record 10 of Set 10 | vagur
# Processing Record 11 of Set 10 | acarau
# Processing Record 12 of Set 10 | nioro
# Processing Record 13 of Set 10 | oum hadjer
# Processing Record 14 of Set 10 | port hedland
# Processing Record 15 of Set 10 | almunecar
# Processing Record 16 of Set 10 | yeletskiy
# City not found. Skipping
# Processing Record 17 of Set 10 | wilkie
# Processing Record 18 of Set 10 | dilla
# Processing Record 19 of Set 10 | farafangana
# Processing Record 20 of Set 10 | katherine
# Processing Record 21 of Set 10 | lobito
# Processing Record 22 of Set 10 | uusikaupunki
# Processing Record 23 of Set 10 | itarema
# Processing Record 24 of Set 10 | ahuimanu
# Processing Record 25 of Set 10 | petrovskoye
# Processing Record 26 of Set 10 | qaqortoq
# Processing Record 27 of Set 10 | rio tuba
# Processing Record 28 of Set 10 | kahului
# Processing Record 29 of Set 10 | dudinka
# Processing Record 30 of Set 10 | tonj
# Processing Record 31 of Set 10 | port hardy
# Processing Record 32 of Set 10 | ishikari
# Processing Record 33 of Set 10 | nantucket
# Processing Record 34 of Set 10 | eskasem
# City not found. Skipping
# Processing Record 35 of Set 10 | ostrovnoy
# Processing Record 36 of Set 10 | verkh-chebula
# Processing Record 37 of Set 10 | matara
# Processing Record 38 of Set 10 | eyl
# Processing Record 39 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 10 | saint george
# Processing Record 41 of Set 10 | vikesa
# Processing Record 42 of Set 10 | ambunti
# Processing Record 43 of Set 10 | sioux lookout
# Processing Record 44 of Set 10 | puerto el triunfo
# Processing Record 45 of Set 10 | naryan-mar
# Processing Record 46 of Set 10 | tvoroyri
# Processing Record 47 of Set 10 | neiafu
# Processing Record 48 of Set 10 | praya
# Processing Record 49 of Set 10 | zinder
# Processing Record 50 of Set 10 | iralaya
# Processing Record 1 of Set 11 | daru
# Processing Record 2 of Set 11 | port moresby
# Processing Record 3 of Set 11 | valparaiso
# Processing Record 4 of Set 11 | samarai
# Processing Record 5 of Set 11 | seymchan
# Processing Record 6 of Set 11 | komsomolets
# Processing Record 7 of Set 11 | sistranda
# Processing Record 8 of Set 11 | liverpool
# Processing Record 9 of Set 11 | dingle
# Processing Record 10 of Set 11 | nsanje
# Processing Record 11 of Set 11 | krasnoselkup
# Processing Record 12 of Set 11 | muroto
# Processing Record 13 of Set 11 | ariquemes
# Processing Record 14 of Set 11 | aksarka
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | slave lake
# Processing Record 17 of Set 11 | marcona
# City not found. Skipping
# Processing Record 18 of Set 11 | rundu
# Processing Record 19 of Set 11 | springbok
# Processing Record 20 of Set 11 | kapoeta
# Processing Record 21 of Set 11 | basco
# Processing Record 22 of Set 11 | bonavista
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | adre
# Processing Record 25 of Set 11 | sangar
# Processing Record 26 of Set 11 | skjervoy
# Processing Record 27 of Set 11 | potiskum
# Processing Record 28 of Set 11 | kryve ozero
# Processing Record 29 of Set 11 | wageningen
# Processing Record 30 of Set 11 | meyungs
# City not found. Skipping
# Processing Record 31 of Set 11 | ciras
# City not found. Skipping
# Processing Record 32 of Set 11 | saleaula
# City not found. Skipping
# Processing Record 33 of Set 11 | raga
# Processing Record 34 of Set 11 | high level
# Processing Record 35 of Set 11 | hauterive
# Processing Record 36 of Set 11 | waipawa
# Processing Record 37 of Set 11 | shimoda
# Processing Record 38 of Set 11 | vostok
# Processing Record 39 of Set 11 | kashi
# Processing Record 40 of Set 11 | kamaishi
# Processing Record 41 of Set 11 | harper
# Processing Record 42 of Set 11 | catamarca
# Processing Record 43 of Set 11 | tabarqah
# City not found. Skipping
# Processing Record 44 of Set 11 | byron bay
# Processing Record 45 of Set 11 | amapa
# Processing Record 46 of Set 11 | ogaminana
# Processing Record 47 of Set 11 | clinton
# Processing Record 48 of Set 11 | bandundu
# Processing Record 49 of Set 11 | margate
# Processing Record 50 of Set 11 | halifax
# Processing Record 1 of Set 12 | vardo
# Processing Record 2 of Set 12 | sawtell
# Processing Record 3 of Set 12 | saldanha
# Processing Record 4 of Set 12 | pangody
# Processing Record 5 of Set 12 | espanola
# Processing Record 6 of Set 12 | stranda
# Processing Record 7 of Set 12 | the valley
# Processing Record 8 of Set 12 | lata
# Processing Record 9 of Set 12 | suzu
# City not found. Skipping
# Processing Record 10 of Set 12 | asau
# Processing Record 11 of Set 12 | zhigansk
# Processing Record 12 of Set 12 | igarka
# Processing Record 13 of Set 12 | spornoye
# Processing Record 14 of Set 12 | pahrump
# Processing Record 15 of Set 12 | kamina
# Processing Record 16 of Set 12 | xining
# Processing Record 17 of Set 12 | maceio
# Processing Record 18 of Set 12 | ust-nera
# Processing Record 19 of Set 12 | salvador
# Processing Record 20 of Set 12 | phan thiet
# Processing Record 21 of Set 12 | halmstad
# Processing Record 22 of Set 12 | duldurga
# Processing Record 23 of Set 12 | tlapacoyan
# Processing Record 24 of Set 12 | san quintin
# Processing Record 25 of Set 12 | coronado
# Processing Record 26 of Set 12 | nelson bay
# Processing Record 27 of Set 12 | boa esperanca do sul
# Processing Record 28 of Set 12 | kishapu
# Processing Record 29 of Set 12 | henties bay
# Processing Record 30 of Set 12 | road town
# Processing Record 31 of Set 12 | tubuala
# Processing Record 32 of Set 12 | metehara
# City not found. Skipping
# Processing Record 33 of Set 12 | stekolnyy
# City not found. Skipping
# Processing Record 34 of Set 12 | kutno
# Processing Record 35 of Set 12 | kant
# Processing Record 36 of Set 12 | luanda
# Processing Record 37 of Set 12 | clearwater
# Processing Record 38 of Set 12 | kagoro
# Processing Record 39 of Set 12 | lorengau
# Processing Record 40 of Set 12 | kalanchak
# Processing Record 41 of Set 12 | tual
# Processing Record 42 of Set 12 | biltine
# Processing Record 43 of Set 12 | mitha tiwana
# Processing Record 44 of Set 12 | katobu
# Processing Record 45 of Set 12 | buchanan
# Processing Record 46 of Set 12 | parras
# City not found. Skipping
# Processing Record 47 of Set 12 | goderich
# Processing Record 48 of Set 12 | healdsburg
# Processing Record 49 of Set 12 | fevik
# Processing Record 50 of Set 12 | kirakira
# Processing Record 1 of Set 13 | komsomolskiy
# Processing Record 2 of Set 13 | artyom
# Processing Record 3 of Set 13 | roald
# Processing Record 4 of Set 13 | seddon
# Processing Record 5 of Set 13 | oktyabrskoye
# Processing Record 6 of Set 13 | bumba
# Processing Record 7 of Set 13 | toliary
# City not found. Skipping
# Processing Record 8 of Set 13 | irbeyskoye
# Processing Record 9 of Set 13 | christchurch
# Processing Record 10 of Set 13 | dawei
# Processing Record 11 of Set 13 | zaplyusye
# City not found. Skipping
# Processing Record 12 of Set 13 | dandong
# Processing Record 13 of Set 13 | upington
# Processing Record 14 of Set 13 | koumac
# Processing Record 15 of Set 13 | port-cartier
# Processing Record 16 of Set 13 | plettenberg bay
# Processing Record 17 of Set 13 | villanueva
# Processing Record 18 of Set 13 | ornskoldsvik
# Processing Record 19 of Set 13 | longyearbyen
# Processing Record 20 of Set 13 | shitanjing
# Processing Record 21 of Set 13 | batemans bay
# Processing Record 22 of Set 13 | amli
# Processing Record 23 of Set 13 | qasigiannguit
# Processing Record 24 of Set 13 | snyder
# Processing Record 25 of Set 13 | chivilcoy
# Processing Record 26 of Set 13 | kerewan
# Processing Record 27 of Set 13 | marzuq
# Processing Record 28 of Set 13 | port-gentil
# Processing Record 29 of Set 13 | san rafael
# Processing Record 30 of Set 13 | egvekinot
# Processing Record 31 of Set 13 | venado tuerto
# Processing Record 32 of Set 13 | flin flon
# Processing Record 33 of Set 13 | gobabis
# Processing Record 34 of Set 13 | motril
# Processing Record 35 of Set 13 | agirish
# Processing Record 36 of Set 13 | riverton
# Processing Record 37 of Set 13 | eravur
# Processing Record 38 of Set 13 | swellendam
# Processing Record 39 of Set 13 | turtas
# Processing Record 40 of Set 13 | togur
# Processing Record 41 of Set 13 | half moon bay
# Processing Record 42 of Set 13 | mango
# Processing Record 43 of Set 13 | grindavik
# Processing Record 44 of Set 13 | lasa
# Processing Record 45 of Set 13 | sao desiderio
# Processing Record 46 of Set 13 | shirokiy
# Processing Record 47 of Set 13 | ketovo
# Processing Record 48 of Set 13 | shieli
# Processing Record 49 of Set 13 | usevya
# Processing Record 50 of Set 13 | zarubino
# Processing Record 1 of Set 14 | tatishchevo
# Processing Record 2 of Set 14 | santa marta
# Processing Record 3 of Set 14 | emerald
# Processing Record 4 of Set 14 | hambantota
# Processing Record 5 of Set 14 | hohhot
# Processing Record 6 of Set 14 | sakakah
# Processing Record 7 of Set 14 | chai badan
# Processing Record 8 of Set 14 | panaba
# Processing Record 9 of Set 14 | kidal
# Processing Record 10 of Set 14 | azimur
# City not found. Skipping
# Processing Record 11 of Set 14 | eureka
# Processing Record 12 of Set 14 | kinshasa
# Processing Record 13 of Set 14 | barra do garcas
# Processing Record 14 of Set 14 | krasnoborsk
# Processing Record 15 of Set 14 | khasan
# Processing Record 16 of Set 14 | gaozhou
# Processing Record 17 of Set 14 | paka
# Processing Record 18 of Set 14 | glendive
# Processing Record 19 of Set 14 | rawson
# Processing Record 20 of Set 14 | tabory
# Processing Record 21 of Set 14 | bagdarin
# Processing Record 22 of Set 14 | baiyin
# Processing Record 23 of Set 14 | dzaoudzi
# Processing Record 24 of Set 14 | baruun-urt
# Processing Record 25 of Set 14 | yulara
# Processing Record 26 of Set 14 | san jose
# Processing Record 27 of Set 14 | tanjong sepat
# City not found. Skipping
# Processing Record 28 of Set 14 | barceloneta
# Processing Record 29 of Set 14 | haradok
# Processing Record 30 of Set 14 | magole
# Processing Record 31 of Set 14 | fairbanks
# Processing Record 32 of Set 14 | muzhi
# Processing Record 33 of Set 14 | itaueira
# Processing Record 34 of Set 14 | obo
# Processing Record 35 of Set 14 | campoverde
# Processing Record 36 of Set 14 | waiouru
# Processing Record 37 of Set 14 | awbari
# Processing Record 38 of Set 14 | keti bandar
# Processing Record 39 of Set 14 | gigmoto
# Processing Record 40 of Set 14 | moose factory
# Processing Record 41 of Set 14 | muros
# Processing Record 42 of Set 14 | namibe
# Processing Record 43 of Set 14 | pirenopolis
# Processing Record 44 of Set 14 | marsa matruh
# Processing Record 45 of Set 14 | monastyrshchina
# Processing Record 46 of Set 14 | santo antonio do ica
# Processing Record 47 of Set 14 | novodugino
# Processing Record 48 of Set 14 | rungata
# City not found. Skipping
# Processing Record 49 of Set 14 | muriwai beach
# Processing Record 50 of Set 14 | sola
# Processing Record 1 of Set 15 | maldonado
# Processing Record 2 of Set 15 | palmer
# Processing Record 3 of Set 15 | krabi
# Processing Record 4 of Set 15 | ambatolampy
# Processing Record 5 of Set 15 | merauke
# Processing Record 6 of Set 15 | los llanos de aridane
# Processing Record 7 of Set 15 | anadyr
# Processing Record 8 of Set 15 | kez
# Processing Record 9 of Set 15 | victor harbor
# Processing Record 10 of Set 15 | westminster
# Processing Record 11 of Set 15 | nizhnyaya poyma
# Processing Record 12 of Set 15 | columbus
# Processing Record 13 of Set 15 | xichang
# Processing Record 14 of Set 15 | khonuu
# City not found. Skipping
# Processing Record 15 of Set 15 | qax
# Processing Record 16 of Set 15 | malanje
# Processing Record 17 of Set 15 | berlin
# Processing Record 18 of Set 15 | balkanabat
# Processing Record 19 of Set 15 | salalah
# Processing Record 20 of Set 15 | chaplynka
# Processing Record 21 of Set 15 | velka bites
# Processing Record 22 of Set 15 | port shepstone
# Processing Record 23 of Set 15 | edd
# Processing Record 24 of Set 15 | kaseda
# Processing Record 25 of Set 15 | tazmalt
# Processing Record 26 of Set 15 | cotonou
# Processing Record 27 of Set 15 | barcelos
# Processing Record 28 of Set 15 | toritama
# Processing Record 29 of Set 15 | tayoltita
# Processing Record 30 of Set 15 | olinda
# Processing Record 31 of Set 15 | bitung
# Processing Record 32 of Set 15 | mange
# Processing Record 33 of Set 15 | nguiu
# City not found. Skipping
# Processing Record 34 of Set 15 | benguela
# Processing Record 35 of Set 15 | morant bay
# Processing Record 36 of Set 15 | semey
# Processing Record 37 of Set 15 | onega
# Processing Record 38 of Set 15 | kandi
# Processing Record 39 of Set 15 | coalville
# Processing Record 40 of Set 15 | medicine hat
# Processing Record 41 of Set 15 | belmonte
# Processing Record 42 of Set 15 | labuhan
# Processing Record 43 of Set 15 | monduli
# Processing Record 44 of Set 15 | adilabad
# Processing Record 45 of Set 15 | guiratinga
# Processing Record 46 of Set 15 | chernyshevskiy
# Processing Record 47 of Set 15 | ialibu
# Processing Record 48 of Set 15 | oriximina
# Processing Record 49 of Set 15 | sibolga
# Processing Record 50 of Set 15 | tasbuget
# City not found. Skipping
# Processing Record 1 of Set 16 | safwah
# City not found. Skipping
# Processing Record 2 of Set 16 | zhaoyuan
# Processing Record 3 of Set 16 | bac lieu
# Processing Record 4 of Set 16 | yumen
# Processing Record 5 of Set 16 | salinopolis
# Processing Record 6 of Set 16 | ayan
# Processing Record 7 of Set 16 | beira
# Processing Record 8 of Set 16 | vestmannaeyjar
# Processing Record 9 of Set 16 | mahajanga
# Processing Record 10 of Set 16 | tocopilla
# Processing Record 11 of Set 16 | ternate
# Processing Record 12 of Set 16 | figeac
# Processing Record 13 of Set 16 | panalingaan
# Processing Record 14 of Set 16 | kungurtug
# Processing Record 15 of Set 16 | gat
# Processing Record 16 of Set 16 | mujiayingzi
# Processing Record 17 of Set 16 | point pedro
# Processing Record 18 of Set 16 | haines junction
# Processing Record 19 of Set 16 | antipovka
# Processing Record 20 of Set 16 | purpe
# Processing Record 21 of Set 16 | keuruu
# Processing Record 22 of Set 16 | vila velha
# Processing Record 23 of Set 16 | palauig
# Processing Record 24 of Set 16 | micheweni
# Processing Record 25 of Set 16 | karakol
# Processing Record 26 of Set 16 | general roca
# Processing Record 27 of Set 16 | maghama
# City not found. Skipping
# Processing Record 28 of Set 16 | pangnirtung
# Processing Record 29 of Set 16 | bellevue
# Processing Record 30 of Set 16 | angoche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 720

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0           Kodiak      US  2021-11-08 03:25:25  57.7900 -152.4072     31.55
# 1          Mataura      NZ  2021-11-08 03:25:25 -46.1927  168.8643     72.90
# 2     Punta Arenas      CL  2021-11-08 03:24:53 -53.1500  -70.9167     44.71
# 3       Butaritari      KI  2021-11-08 03:25:26   3.0707  172.7902     82.06
# 4      Yellowknife      CA  2021-11-08 03:25:26  62.4560 -114.3525     27.41
# 5      Port Alfred      ZA  2021-11-08 03:25:27 -33.5906   26.8910     64.42
# 6           Kiunga      PG  2021-11-08 03:23:11  -6.1219  141.2906     92.46
# 7  San Luis Obispo      US  2021-11-08 03:25:28  35.3666 -120.5343     58.75
# 8   Saint-Philippe      RE  2021-11-08 03:25:29 -21.3585   55.7679     79.48
# 9           Itoman      JP  2021-11-08 03:25:29  26.1247  127.6694     79.18
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        90          97       12.88          light snow
# 1        40         100        1.14     overcast clouds
# 2        70          40       16.11    scattered clouds
# 3        70          13       10.85          few clouds
# 4        99          90        1.99          light snow
# 5        86         100        7.74          light rain
# 6        54          81        2.48       broken clouds
# 7        44           1        3.44           clear sky
# 8        79          40        9.69    scattered clouds
# 9        72          75       10.36       broken clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
